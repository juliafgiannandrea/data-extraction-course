# %% [markdown]
# # Lab 02 - Extração de Dados: Arquivos Planos
# **Disciplina:** Extração e Preparação de Dados | **Professor:** Luis Aramis
#
# Neste laboratório, vamos praticar a leitura de diferentes formatos de arquivos planos (CSV, Excel) e lidar com problemas comuns como codificação, delimitadores e metadados.

# %% [markdown]
# ## 1. Setup
# Importe a biblioteca pandas.

# %%
# Seu código aqui
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Seu código aqui
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## 2. CSV Padrão
# Carregue o arquivo `vendas.csv` e exiba as 5 primeiras linhas.

# %%
vendas = pd.read_csv('vendas.csv')
vendas.head(5)
# Out:
#    id_venda        data   produto  quantidade  preco_unitario     total
# 0         1  2024-01-01   Teclado           1         2852.92   2852.92
# 1         2  2024-01-02   Teclado           7         3249.47  22746.29
# 2         3  2024-01-03   Teclado           7         4104.96  28734.72
# 3         4  2024-01-04   Teclado           1          870.74    870.74
# 4         5  2024-01-05  Notebook           7         3614.27  25299.89

# %% [markdown]
# ## 3. CSV com Problemas (Delimitador e Encoding)
# Tente carregar o arquivo `produtos_brasil.csv`.
# Você encontrará erros. Corrija utilizando os parâmetros `sep` e `encoding`.
# Obs: O separador é `;` e o encoding é `latin1`.

# %%
produtos = pd.read_csv('produtos_brasil.csv',encoding='latin-1',sep=";")
produtos.head(5)
# Out:
#     id           nome preco_reais
# 0  101           Café       32,75
# 1  102         Feijão       49,96
# 2  103  Pão de Queijo       32,98
# 3  104           Açaí        6,24
# 4  105        Guaraná       19,24

# %% [markdown]
# ## 4. Excel com Múltiplas Abas
# Carregue a aba 'Jan' do arquivo `relatorio_financeiro.xlsx`.
# Observe que o cabeçalho não está na primeira linha. Use o parâmetro `header` ou `skiprows` para corrigir.

# %%
fin = pd.read_excel('relatorio_financeiro.xlsx',sheet_name='Jan', header=0)
fin.head()
# Out:
#   RELATÓRIO FINANCEIRO Unnamed: 1
# 0         CONFIDENCIAL        NaN
# 1                  NaN        NaN
# 2                  Dia    Receita
# 3                    1       4475
# 4                    2       2561

# %% [markdown]
# ## 5. Delimitadores Exóticos
# Carregue o arquivo `movies.csv`. Ele usa o caractere `|` como separador.

# %%
movies = pd.read_csv("movies.csv",sep="|")
movies.head()
# Out:
#    movie_id         title  year
# 0         1     Inception  2010
# 1         2    The Matrix  1999
# 2         3  Interstellar  2014
# 3         4      Parasite  2019
# 4         5      Avengers  2012

# %% [markdown]
# ## 6. Arquivos com Metadados no Início
# O arquivo `ibge_metadata.csv` possui 3 linhas de texto antes do cabeçalho real.
# Use o parâmetro `skiprows` para ignorá-las. Dica: encoding `cp1252`.

# %%
ibge = pd.read_csv('ibge_metadata.csv', encoding='cp1252',skiprows=3)
ibge.head()
# Out:
#    cod_municipio  nome_municipio  populacao_estimada
# 0        3550308       São Paulo            11451245
# 1        3304557  Rio de Janeiro             6211423
# 2        3106200  Belo Horizonte             2438423

# %% [markdown]
# ---
# ## PARTE 2: APROFUNDAMENTO
# Tratamento de Arquivos Massivos e Múltiplos Arquivos.

# %% [markdown]
# ## 7. Leitura em Chunks (Big Files)
# O arquivo `big_file.csv` simula um arquivo grande. Leia-o em pedaços (chunks) de 10.000 linhas e exiba o tipo do objeto resultante.

# %%
chunks = pd.read_csv('big_file.csv', chunksize=10000)
df = pd.concat(chunks)
df.head()
# Out:
#     A   B   C   D   E
# 0  52  54   8  11  66
# 1  22  10  52  47  77
# 2   2  69  58  65  18
# 3  91  13  23  19  68
# 4  53  23  36  33  73

# %% [markdown]
# ## 8. Linhas com Erro (Bad Lines)
# O arquivo `bad_lines.csv` possui linhas quebradas. Tente carregar ignorando as linhas com erro utilizando `on_bad_lines`.

# %%
bad = pd.read_csv('bad_lines.csv', on_bad_lines='skip')
bad.head()
# Out:
#    id   nome            email
# 0   1   Joao   joao@email.com
# 1   3  Pedro  pedro@email.com

# %% [markdown]
# ## 9. Múltiplos Arquivos (Glob)
# Use a biblioteca `glob` para listar os arquivos na pasta `batch_data/` e carregá-los em um único DataFrame com `pd.concat`.

# %%
import glob 
files = glob.glob("batch_data/*.csv") #listar arquivos na

# %%
dfs = []
for file in files:
    df= pd.read_csv(file)
    dfs.append(df)
   
final = pd.concat(dfs)
final
# Out:
#    id       val
# 0  20  0.747106
# 1  21  0.177963
# 2  22  0.914852
# 3  23  0.610660
# 4  24  0.397687
# 5  25  0.827235
# 6  26  0.482531
# 7  27  0.370568
# 8  28  0.916949
# 9  29  0.532984
# 0   0  0.781380
# 1   1  0.133207
# 2   2  0.519294
# 3   3  0.836694
# 4   4  0.811590
# 5   5  0.031818
# 6   6  0.457655
# 7   7  0.282596
# 8   8  0.648938
# 9   9  0.643613
# 0  10  0.694176
# 1  11  0.932038
# 2  12  0.630918
# 3  13  0.246435
# 4  14  0.191149
# 5  15  0.884932
# 6  16  0.067014
# 7  17  0.105127
# 8  18  0.918379
# 9  19  0.457547

# %% [markdown]
# ---
# ## PARTE 3: NÍVEL EXPERT
# Otimização e Limpeza Avançada.

# %% [markdown]
# ## 10. Otimização de Memória (Downcasting)
# 1. Carregue o arquivo `big_file.csv` inteiro (se couber) ou um chunk.
# 2. Verifique o uso de memória com `.info(memory_usage='deep')`.
# 3. Converta uma coluna numérica para `float32` ou `int32` e verifique a réduction do uso de memória.

# %%
big = pd.read_csv('big_file.csv')
big.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50000 non-null  int64
#  1   B       50000 non-null  int64
#  2   C       50000 non-null  int64
#  3   D       50000 non-null  int64
#  4   E       50000 non-null  int64
# dtypes: int64(5)
# memory usage: 1.9 MB

# %%
big.info() #descobir os tipos numéricos de cada coluna 

big['A'] = big['A'].astype('int32')

big.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50000 non-null  int64
#  1   B       50000 non-null  int64
#  2   C       50000 non-null  int64
#  3   D       50000 non-null  int64
#  4   E       50000 non-null  int64
# dtypes: int64(5)
# memory usage: 1.9 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50000 non-null  int32
#  1   B       50000 non-null  int64
#  2   C       50000 non-null  int64
#  3   D       50000 non-null  int64
#  4   E       50000 non-null  int64
# dtypes: int32(1), int64(4)
# memory usage: 1.7 MB

# %% [markdown]
# ## 11. Extração com Regex
# Suponha a seguinte coluna de texto sujo. Crie um DataFrame com ela e use `str.extract` para obter apenas o código numérico.
# ```python
# dados = {'Info': ['Produto: [123] - Vendido', 'Produto: [456] - Estoque', 'Produto: [789] - Devolvido']}
# ```

# %%
dados = {'Info': ['Produto: [123] - Vendido', 'Produto: [456] - Estoque', 'Produto: [789] - Devolvido']}
df = pd.DataFrame(dados)
df.head()
# Out:
#                          Info
# 0    Produto: [123] - Vendido
# 1    Produto: [456] - Estoque
# 2  Produto: [789] - Devolvido

# %%
df['codigo'] = df['Info'].str.extract(r'\[(\d+)\]')
df['status'] = df['Info'].str.replace(r'Produto:\s*\[\d+\]\s*-\s*', '', regex=True)

df.head()
produtos = df[['status', 'codigo']]
produtos
# Out:
#       status codigo
# 0    Vendido    123
# 1    Estoque    456
# 2  Devolvido    789

# %% [markdown]
# ---
# ## 12. DESAFIO PARA CASA (Real Data)
# 1. Entre no site [dados.gov.br](https://dados.gov.br) ou [Kaggle](https://kaggle.com).
# 2. Baixe um dataset CSV de seu interesse (tamanho mínimo: 1000 linhas).
# 3. Carregue-o no pandas, tratando problemas de encoding/separador se houver.
# 4. Exiba um `.info()` e `.describe()`.
# 5. Responda: Qual o tamanho do arquivo em memória?

# %%
#base 
base_bmw = pd.read_csv('bmw_global_sales_2018_2025.csv')
base_bmw.head()
base_bmw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3072 entries, 0 to 3071
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              3072 non-null   int64
#  1   Month             3072 non-null   int64
#  2   Region            3072 non-null   str
#  3   Model             3072 non-null   str
#  4   Units_Sold        3072 non-null   int64
#  5   Avg_Price_EUR     3072 non-null   int64
#  6   Revenue_EUR       3072 non-null   int64
#  7   BEV_Share         3072 non-null   float64
#  8   Premium_Share     3072 non-null   float64
#  9   GDP_Growth        3072 non-null   float64
#  10  Fuel_Price_Index  3072 non-null   float64
# dtypes: float64(4), int64(5), str(2)
# memory usage: 264.1 KB

# %%
base_bmw.describe()
# Out:
#               Year        Month    Units_Sold  Avg_Price_EUR   Revenue_EUR  \
# count  3072.000000  3072.000000   3072.000000    3072.000000  3.072000e+03
# mean   2021.500000     6.500000   7980.288086   63854.561523  5.113995e+08
# std       2.291661     3.452615   3174.917444   14655.891299  2.431185e+08
# min    2018.000000     1.000000   2379.000000   40011.000000  1.045314e+08
# 25%    2019.750000     3.750000   5225.500000   54500.250000  3.125504e+08
# 50%    2021.500000     6.500000   7985.500000   63493.000000  4.808690e+08
# 75%    2023.250000     9.250000  10528.250000   71489.500000  6.709141e+08
# max    2025.000000    12.000000  15914.000000   93994.000000  1.433482e+09
#
#          BEV_Share  Premium_Share   GDP_Growth  Fuel_Price_Index
# count  3072.000000    3072.000000  3072.000000       3072.000000
# mean      0.107572      14.660234     3.057526          1.176224
# std       0.058099       5.334604     1.018103          0.118123
# min      -0.015000       5.090000     0.100000          0.920000
# 25%       0.057000      12.275000     2.370000          1.080000
# 50%       0.108000      16.260000     3.060000          1.180000
# 75%       0.157250      18.932500     3.852500          1.270000
# max       0.223000      20.970000     5.820000          1.410000

# %%
#Tamanho do arquivo em memória: 
base_bmw.info(memory_usage='deep')
#540.1 KB
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3072 entries, 0 to 3071
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              3072 non-null   int64
#  1   Month             3072 non-null   int64
#  2   Region            3072 non-null   str
#  3   Model             3072 non-null   str
#  4   Units_Sold        3072 non-null   int64
#  5   Avg_Price_EUR     3072 non-null   int64
#  6   Revenue_EUR       3072 non-null   int64
#  7   BEV_Share         3072 non-null   float64
#  8   Premium_Share     3072 non-null   float64
#  9   GDP_Growth        3072 non-null   float64
#  10  Fuel_Price_Index  3072 non-null   float64
# dtypes: float64(4), int64(5), str(2)
# memory usage: 540.1 KB
